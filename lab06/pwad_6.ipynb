# %% [markdown]
# # Język Python w Analizie Danych
# # Zadania praktyczne

# %% [markdown]
# ## Cel zajęć
#
# - Utrwalenie wiedzy i przećwiczenie praktyczne zakresu materiałów z laboratorium 1-4

# %%
# Instalacja modułów
# !pip install matplotlib seaborn numpy pandas

# %%
# Import modułów

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Wczytanie danych
df_csv = pd.read_csv('data/data05.csv')
df_csv.head()
# Out:
#    Country    Year        Attack Type     Target Industry  \
# 0    China  2019.0           Phishing           Education
# 1    China  2019.0         Ransomware              Retail
# 2    India  2017.0  Man-in-the-Middle                  IT
# 3       UK  2024.0         Ransomware  Telecommunications
# 4  Germany  2018.0  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                  773169.0  Hacker Group
# 1                          62.19                  295961.0  Hacker Group
# 2                          38.65                  605895.0  Hacker Group
# 3                          41.44                  659320.0  Nation-state
# 4                          74.41                  810682.0       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# 1          Unpatched Software               Firewall
# 2              Weak Passwords                    VPN
# 3                         NaN     AI-based Detection
# 4          Social Engineering                    VPN
#
#    Incident Resolution Time (in Hours)
# 0                                 63.0
# 1                                 71.0
# 2                                 20.0
# 3                                  7.0
# 4                                 68.0

# %% [markdown]
# ### Zadanie 1
# Dokonaj eksploracyjnej analizy danych. Przedstaw swoje wnioski dotyczące dostarczonych danych i odpowiedz na pytania poniżej popierając się danymi analitycznymi.

# %%
# TODO: EDA

# %% [markdown]
# Jaki sektor jest najbardziej narażony na ataki hackerskie? Jak prezentuje się ryzyko w innych sektorach?

# %% [markdown]
# W którym kraju odnotowano największe straty przez ataki? Jaki jest stosunek tej wartości względem pozostałych strat z innych krajów?

# %% [markdown]
# Jakich ataków było najwięcej, a jakich najmniej na przestrzeni lat?

# %% [markdown]
# Czy istnieją zależności między miejscem ataku, podmiotem atakującym, typem ataku i celem ataku?

# %% [markdown]
# Czy z danych wynika że lepiej dla atakującego, aby atak trwał jak najdłużej, czy aby zaatakować jak najwięcej użytkowników?

# %% [markdown]
# Jak rozkłada się częstotliwość ataków na przestrzeni lat? Czy tendencja jest spadkowa czy wręcz przeciwnie?
